# %%
from tools import *

# %%
run_notebook('AFM.ipynb')
convert_all_ascii()
# Out:
# 20150424_m19_beforeanneal.002
# 20150425_m19_beforeanneal.001
# 20150425_m19_beforeanneal.002
# 20150425_m19_beforeanneal.003
# 20150425_m19_beforeanneal.004
# 20150425_m19_beforeanneal.005
# 20150426_m19_afteranneal.000
# 20150426_m19_afteranneal.001
# 20150426_m19_afteranneal.002
# 20150426_m19_afteranneal.003
# 20150426_m19_afteranneal.004

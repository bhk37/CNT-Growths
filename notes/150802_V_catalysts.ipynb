# %%
sys.path.append('../src')

from tools import *
run_notebook('../src/AFM.ipynb')

# %% [markdown]
# #V7 - 1hr air anneal

# %%
fn = '150801_v7_1hr_air_anneal.001'
im, size = read_ascii(fn)
cats = locate_cats(im, smoothness = 4, max_rad = 15)
plot_cat_map(im, cats, size = size)
plot_height_dist(cats, hmax = 10)
print('No. cats: %d' % len(cats))
# Out:
# No. cats: 499

# %% [markdown]
# #V8 - 2hr air anneal

# %%
fn = '150801_v8_2hr_air_anneal.000'
im, size = read_ascii(fn)
cats = locate_cats(im, smoothness = 4, max_rad = 20)
plot_cat_map(im, cats, size = size)
plot_height_dist(cats, hmax = 10)
print('No. cats: %d' % len(cats))
# Out:
# No. cats: 371

# %%
sys.path.append('../src')

from tools import *
run_notebook('../src/AFM.ipynb')

# %% [markdown]
# #V7

# %% [markdown]
# ##1hr air anneal

# %%
fn = '150803_v7_1hr_air_anneal_cross.004'
im, size = read_ascii(fn)
cats = plot_all(im[55:455,:], smoothness = 2.5, max_rad = 15)
print('No. cats: %d' % len(cats))
# Out:
# No. cats: 390

# %% [markdown]
# ##1+1hr air anneal

# %%
fn = '150803_v7_1+1hr_air_anneal_cross.000'
im, size = read_ascii(fn)
cats = plot_all(im[:400,:], smoothness = 2.5, max_rad = 15)
print('No. cats: %d' % len(cats))
# Out:
# No. cats: 461

# %% [markdown]
# Unlike with W9, there is no noticeable change between the first and second anneals.

# %% [markdown]
# #V8 - 2hr air anneal

# %%
fn = '150801_v8_2hr_air_anneal.000'
im, size = read_ascii(fn)
cats = plot_all(im, size = size, smoothness = 3, max_rad = 20)
print('No. cats: %d' % len(cats))
# Out:
# No. cats: 433

# %% [markdown]
# #V5 - 1hr air anneal

# %%
fn = '150803_v5_1hr_air_anneal.002'
im, size = read_ascii(fn)
cats = plot_all(im, size = size, smoothness = 2.5, max_rad = 15)
print('No. cats: %d' % len(cats))
# Out:
# No. cats: 719

# %% [markdown]
# #V3 - 1hr air anneal

# %%
fn = '150803_v3_1hr_air_anneal.000'
im, size = read_ascii(fn)
cats = plot_all(im, size = size, smoothness = 2.5, max_rad = 15)
print('No. cats: %d' % len(cats))
# Out:
# No. cats: 759

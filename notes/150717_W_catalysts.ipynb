# %%
sys.path.append('../src')

from tools import *
run_notebook('../src/AFM.ipynb')

# %% [markdown]
# #W9

# %% [markdown]
# ##1hr air anneal

# %%
fn = '150729_w09_1hr_air_anneal.009'
im, size = read_ascii(fn)
im_red = im[0.2*shape(im)[0]:0.8*shape(im)[0], :]
size_red = (size[0], size[1]*0.6)
plot_all(im_red, size = size_red, smoothness = 3, max_rad = 20, hmax = 10)

# %% [markdown]
# ##1+1hr air anneal (i.e. 2 hrs total)

# %%
fn = '150731_w09_2hr_air_anneal.001'
im, size = read_ascii(fn)
plot_all(im, size = size, smoothness = 25, max_rad = 60, hbins = 30)

# %% [markdown]
# **Conclusion:** During the second anneal, the catalyst particles clumped up dramatically.

# %% [markdown]
# #W10 - 1hr air anneal

# %%
fn = '150729_w10_1hr_air_anneal.003'
im, size = read_ascii(fn)
plot_all(im, size = size, smoothness = 2, max_rad = 15)

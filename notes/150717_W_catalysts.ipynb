# %%
sys.path.append('../src')

from tools import *
run_notebook('../src/AFM.ipynb')

# %% [markdown]
# #W9

# %% [markdown]
# ##1hr air anneal

# %%
fn = '150729_w09_1hr_air_anneal.000'
im, size = read_ascii(fn)
plot_image(im, size = size, save = True, filename = fn)

# %%
fn = '150729_w09_1hr_air_anneal.002'
im, size = read_ascii(fn)
plot_image(im, size = size, save = True, filename = fn)

# %%
fn = '150729_w09_1hr_air_anneal.009'
im, size = read_ascii(fn)
plot_image(im, size = size, save = True, filename = fn)

# %%
im_red = im[0.2*shape(im)[0]:0.8*shape(im)[0], :]
size_red = (size[0], size[1]*0.6)
cats = locate_cats(im_red)
plot_cat_map(im_red, cats, size = size_red)
plot_height_dist(cats)

# %% [markdown]
# ##additional 1hr air anneal (2 hrs total)

# %%
fn = '150731_w09_2hr_air_anneal.000'
im, size = read_ascii(fn)
plot_image(im, size = size, save = True, filename = fn)

# %%
fn = '150731_w09_2hr_air_anneal.001'
im, size = read_ascii(fn)
plot_image(im, size = size, save = True, filename = fn)

# %% [markdown]
# #W10 - 1hr air anneal

# %%
fn = '150729_w10_1hr_air_anneal.003'
im, size = read_ascii(fn)
cats = locate_cats(im, smoothness = 2, max_rad = 15)
plot_cat_map(im, cats, size = size)
plot_height_dist(cats)
